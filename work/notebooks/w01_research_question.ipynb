# %% [markdown]
# <a href="https://colab.research.google.com/github/emiliyabdul/START/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/emiliyabdul/START/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the Refresh / Content Opportunity Scoring lane because I want to investigate how observable page and search signals can help prioritize which pages deserve human review first. I find this lane especially interesting because it connects exploratory data analysis, feature engineering, ranking, and machine learning to a practical decision: deciding where limited content and SEO effort should be spent.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The decision is which content pages should be reviewed first when the available editorial or SEO time is limited.
#
# The unit of analysis is a content page.
#
# A content or SEO specialist could use the ranked output to decide which pages to inspect first and then determine whether a page should be refreshed, expanded, protected, pruned, or simply monitored.
#
# A false positive could cause the team to spend limited time reviewing or changing a page that is not a strong opportunity. A false negative could cause a potentially valuable page to receive less attention while resources are spent elsewhere.
#
# Data and ML may help because many observable signals can describe a page's visibility, age, performance, and engagement. Combining these signals may help prioritize pages more consistently than relying on one simple rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# 30,000 content pages were present in the starter dataset. All 30,000 had at least one search impression in the 90-day window. The median number of impressions was 731, and the median content age was 236 days.
# These numbers make the lane worth investigating because the dataset contains many pages with measurable search exposure and established content history. This creates a meaningful prioritization problem: there are many pages to review, but editorial attention is limited.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

# Load the starter dataset
url = "https://raw.githubusercontent.com/emiliyabdul/START/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

# Basic size of the dataset
print(f"Rows: {len(df):,}")
print(f"Columns: {len(df.columns):,}")

# Show a few useful numbers for our lane
print(f"Pages with impressions: {(df['impressions_90d'] > 0).sum():,}")
print(f"Median impressions: {df['impressions_90d'].median():.0f}")
print(f"Median content age (days): {df['content_age_days'].median():.0f}")
# Out:
# Rows: 30,000
# Columns: 44
# Pages with impressions: 30,000
# Median impressions: 731
# Median content age (days): 236

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# The data can show observed relationships between page characteristics and search or engagement outcomes, and a future model may help rank pages for human review. I can use the data to identify patterns and provide decision support.
# I cannot claim that an observed relationship is causal, that refreshing a particular page will cause its performance to improve, or that a high score guarantees that a page should be changed. The goal is to prioritize review based on evidence, not to automatically decide what action will succeed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
